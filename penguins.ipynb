# %%
library(skimr)
library(here)
library(janitor)
library(dplyr)
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ readr     2.1.4
# ✔ ggplot2   3.4.1     ✔ stringr   1.5.0
# ✔ lubridate 1.9.2     ✔ tibble    3.2.0
# ✔ purrr     1.0.1     ✔ tidyr     1.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
library('palmerpenguins')
# Out:
# Warning message:
# "package 'palmerpenguins' was built under R version 4.2.3"

# %% [markdown]
# # Clean data functions

# %% [markdown]
# <b><ol>
# <li>skim_without_charts() >> give the summary about the data set</li>
# <li>glimpse() >> summary of the data
#
# <li>select()
# <li>rename_with()
# <li>clean_names()
# <li>rename(NewName = oldName )
# <ol>

# %% [markdown]
# # Organize

# %% [markdown]
# <b><ol>
#
# <li>filter()
# <li>mean()
# <li>drop_na()
# <li>summarize()
# <li>max()
# <li>group_by()
# <li>arrange()

# %% [markdown]
# # Transform

# %% [markdown]
# <b><ol>
# <li>mutate()
# <li>unite()
# <li>separate()

# %%
skim_without_charts(penguins)
# Out:
# ── Data Summary ────────────────────────
#                            Values
# Name                       penguins
# Number of rows             344
# Number of columns          8
# _______________________
# Column type frequency:
#   factor                   3
#   numeric                  5
# ________________________
# Group variables            None
#
# ── Variable type: factor ───────────────────────────────────────────────────────
#   skim_variable n_missing complete_rate ordered n_unique
# 1 species               0         1     FALSE          3
# 2 island                0         1     FALSE          3
# 3 sex                  11         0.968 FALSE          2
#   top_counts
# 1 Ade: 152, Gen: 124, Chi: 68
# 2 Bis: 168, Dre: 124, Tor: 52
# 3 mal: 168, fem: 165
#
# ── Variable type: numeric ──────────────────────────────────────────────────────
#   skim_variable     n_missing complete_rate   mean      sd     p0    p25    p50
# ...

# %%
glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %%
head(penguins)
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
# out all data in columns species
penguins %>%
select(species)
# Out:
#     species
# 1   Adelie
# 2   Adelie
# 3   Adelie
# 4   Adelie
# 5   Adelie
# 6   Adelie
# 7   Adelie
# 8   Adelie
# 9   Adelie
# 10  Adelie
# 11  Adelie
# 12  Adelie
# 13  Adelie
# 14  Adelie
# 15  Adelie
# 16  Adelie
# 17  Adelie
# 18  Adelie
# 19  Adelie
# 20  Adelie
# 21  Adelie
# 22  Adelie
# 23  Adelie
# 24  Adelie
# 25  Adelie
# 26  Adelie
# 27  Adelie
# 28  Adelie
# 29  Adelie
# 30  Adelie
# ⋮   ⋮
# 315 Chinstrap
# 316 Chinstrap
# 317 Chinstrap
# 318 Chinstrap
# 319 Chinstrap
# 320 Chinstrap
# 321 Chinstrap
# 322 Chinstrap
# 323 Chinstrap
# 324 Chinstrap
# 325 Chinstrap
# 326 Chinstrap
# 327 Chinstrap
# 328 Chinstrap
# 329 Chinstrap
# 330 Chinstrap
# 331 Chinstrap
# 332 Chinstrap
# 333 Chinstrap
# 334 Chinstrap
# 335 Chinstrap
# 336 Chinstrap
# 337 Chinstrap
# 338 Chinstrap
# 339 Chinstrap
# 340 Chinstrap
# 341 Chinstrap
# 342 Chinstrap
# 343 Chinstrap
# 344 Chinstrap

# %%
# out all data in columns except species
# just a supset of variables from a large dataset
penguins %>%
select(-species)
# Out:
#     island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g sex
# 1   Torgersen 39.1           18.7          181               3750        male
# 2   Torgersen 39.5           17.4          186               3800        female
# 3   Torgersen 40.3           18.0          195               3250        female
# 4   Torgersen   NA             NA           NA                 NA        NA
# 5   Torgersen 36.7           19.3          193               3450        female
# 6   Torgersen 39.3           20.6          190               3650        male
# 7   Torgersen 38.9           17.8          181               3625        female
# 8   Torgersen 39.2           19.6          195               4675        male
# 9   Torgersen 34.1           18.1          193               3475        NA
# 10  Torgersen 42.0           20.2          190               4250        NA
# 11  Torgersen 37.8           17.1          186               3300        NA
# ...

# %%
penguins %>% rename(island_new = island)
# Out:
#     species   island_new bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen  39.1           18.7          181
# 2   Adelie    Torgersen  39.5           17.4          186
# 3   Adelie    Torgersen  40.3           18.0          195
# 4   Adelie    Torgersen    NA             NA           NA
# 5   Adelie    Torgersen  36.7           19.3          193
# 6   Adelie    Torgersen  39.3           20.6          190
# 7   Adelie    Torgersen  38.9           17.8          181
# 8   Adelie    Torgersen  39.2           19.6          195
# 9   Adelie    Torgersen  34.1           18.1          193
# 10  Adelie    Torgersen  42.0           20.2          190
# 11  Adelie    Torgersen  37.8           17.1          186
# 12  Adelie    Torgersen  37.8           17.3          180
# 13  Adelie    Torgersen  41.1           17.6          182
# 14  Adelie    Torgersen  38.6           21.2          191
# 15  Adelie    Torgersen  34.6           21.1          198
# ...

# %%
rename_with(penguins, toupper)
# Out:
#     SPECIES   ISLAND    BILL_LENGTH_MM BILL_DEPTH_MM FLIPPER_LENGTH_MM
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %%
# Organise data
arrange()
group_by()
filter()
View()

# %%
penguins %>% arrange(bill_length_mm)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Dream     32.1           15.5          188
# 2   Adelie    Dream     33.1           16.1          178
# 3   Adelie    Torgersen 33.5           19.0          190
# 4   Adelie    Dream     34.0           17.1          185
# 5   Adelie    Torgersen 34.1           18.1          193
# 6   Adelie    Torgersen 34.4           18.4          184
# 7   Adelie    Biscoe    34.5           18.1          187
# 8   Adelie    Torgersen 34.6           21.1          198
# 9   Adelie    Torgersen 34.6           17.2          189
# 10  Adelie    Biscoe    35.0           17.9          190
# 11  Adelie    Biscoe    35.0           17.9          192
# 12  Adelie    Torgersen 35.1           19.4          193
# 13  Adelie    Torgersen 35.2           15.9          186
# 14  Adelie    Biscoe    35.3           18.9          187
# 15  Adelie    Biscoe    35.5           16.2          195
# ...

# %%
penguins %>% arrange(- bill_length_mm)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Gentoo    Biscoe    59.6           17.0          230
# 2   Chinstrap Dream     58.0           17.8          181
# 3   Gentoo    Biscoe    55.9           17.0          228
# 4   Chinstrap Dream     55.8           19.8          207
# 5   Gentoo    Biscoe    55.1           16.0          230
# 6   Gentoo    Biscoe    54.3           15.7          231
# 7   Chinstrap Dream     54.2           20.8          201
# 8   Chinstrap Dream     53.5           19.9          205
# 9   Gentoo    Biscoe    53.4           15.8          219
# 10  Chinstrap Dream     52.8           20.0          205
# 11  Chinstrap Dream     52.7           19.8          197
# 12  Gentoo    Biscoe    52.5           15.6          221
# 13  Gentoo    Biscoe    52.2           17.1          228
# 14  Chinstrap Dream     52.2           18.8          197
# 15  Gentoo    Biscoe    52.1           17.0          230
# ...

# %%
penguins2 = penguins %>% arrange(-bill_length_mm)

# %%
View(penguins2)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Gentoo    Biscoe    59.6           17.0          230
# 2   Chinstrap Dream     58.0           17.8          181
# 3   Gentoo    Biscoe    55.9           17.0          228
# 4   Chinstrap Dream     55.8           19.8          207
# 5   Gentoo    Biscoe    55.1           16.0          230
# 6   Gentoo    Biscoe    54.3           15.7          231
# 7   Chinstrap Dream     54.2           20.8          201
# 8   Chinstrap Dream     53.5           19.9          205
# 9   Gentoo    Biscoe    53.4           15.8          219
# 10  Chinstrap Dream     52.8           20.0          205
# 11  Chinstrap Dream     52.7           19.8          197
# 12  Gentoo    Biscoe    52.5           15.6          221
# 13  Gentoo    Biscoe    52.2           17.1          228
# 14  Chinstrap Dream     52.2           18.8          197
# 15  Gentoo    Biscoe    52.1           17.0          230
# ...

# %%
# group by island length mean
penguins %>% group_by(island) %>% drop_na() %>% summarize(mean_bill_length_mm = mean(bill_length_mm))
# Out:
#   island    mean_bill_length_mm
# 1 Biscoe    45.24847
# 2 Dream     44.22195
# 3 Torgersen 39.03830

# %%
# group by island length max
penguins %>% group_by(island) %>% drop_na() %>% summarize(max_bill_length_mm = max(bill_length_mm))
# Out:
#   island    max_bill_length_mm
# 1 Biscoe    59.6
# 2 Dream     58.0
# 3 Torgersen 46.0

# %%
# group by island and species and summarize by mean and max
penguins %>% group_by(species, island) %>% drop_na() %>% summarize(max_bill_length_mm = max(bill_length_mm), mean_bill_length_mm = mean(bill_length_mm))
# Out:
# `summarise()` has grouped output by 'species'. You can override using the
# `.groups` argument.
#   species   island    max_bill_length_mm mean_bill_length_mm
# 1 Adelie    Biscoe    45.6               38.97500
# 2 Adelie    Dream     44.1               38.52000
# 3 Adelie    Torgersen 46.0               39.03830
# 4 Chinstrap Dream     58.0               48.83382
# 5 Gentoo    Biscoe    59.6               47.56807

# %%
penguins %>% filter(species == 'Adelie')
# Out:
#     species island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie  Torgersen 39.1           18.7          181
# 2   Adelie  Torgersen 39.5           17.4          186
# 3   Adelie  Torgersen 40.3           18.0          195
# 4   Adelie  Torgersen   NA             NA           NA
# 5   Adelie  Torgersen 36.7           19.3          193
# 6   Adelie  Torgersen 39.3           20.6          190
# 7   Adelie  Torgersen 38.9           17.8          181
# 8   Adelie  Torgersen 39.2           19.6          195
# 9   Adelie  Torgersen 34.1           18.1          193
# 10  Adelie  Torgersen 42.0           20.2          190
# 11  Adelie  Torgersen 37.8           17.1          186
# 12  Adelie  Torgersen 37.8           17.3          180
# 13  Adelie  Torgersen 41.1           17.6          182
# 14  Adelie  Torgersen 38.6           21.2          191
# 15  Adelie  Torgersen 34.6           21.1          198
# 16  Adelie  Torgersen 36.6           17.8          185
# ...

# %% [markdown]
# ### Body math by kilograms

# %%
penguins %>% mutate(body_mass_kg = body_mass_g / 1000)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %% [markdown]
# ### Length by meter

# %%
penguins %>% mutate(flipper_length_m = flipper_length_mm / 1000)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...
